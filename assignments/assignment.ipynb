# %%
import re
import nltk
import spacy
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download("stopwords")
nltk.download("punkt_tab")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yuvra\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\yuvra\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\yuvra\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\yuvra\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
text = """
Natural Language Processing, also known as NLP, is one of the most important areas of Artificial Intelligence.
Today, companies use NLP in chatbots, search engines, recommendation systems, social media analytics,
customer feedback analysis, automatic translation, and voice assistants.
 
In 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
online forms, tweets, product comments, and support tickets. However, this text data is often messy.
For example, a customer may write: "I LOVE this product!!! Visit https://example.com/product123 #Amazing #AI".
Another user may write: "The service was not good... I waited 45 minutes and no one replied."
 
Before applying machine learning or deep learning models, we need to clean and prepare the text.
This step is called text preprocessing. It may include converting text to lowercase, removing URLs,
removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
stemming, lemmatization, and sometimes removing emojis or special characters.
 
Good preprocessing can improve the quality of NLP models. However, preprocessing should be done carefully.
For example, removing the word "not" from the sentence "I am not happy" can change the meaning completely.
Similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
can contain useful information about topics, opinions, or trends.
 
Your task is to build a complete NLP preprocessing pipeline for this text.
You should clean the text step by step and observe how the output changes after each step.
"""

# %%
text = text.lower()
print(text)
# Out:
# natural language processing, also known as nlp, is one of the most important areas of artificial intelligence.
# today, companies use nlp in chatbots, search engines, recommendation systems, social media analytics,
# customer feedback analysis, automatic translation, and voice assistants.
#
# in 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
# online forms, tweets, product comments, and support tickets. however, this text data is often messy.
# for example, a customer may write: "i love this product!!! visit https://example.com/product123 #amazing #ai".
# another user may write: "the service was not good... i waited 45 minutes and no one replied."
#
# before applying machine learning or deep learning models, we need to clean and prepare the text.
# this step is called text preprocessing. it may include converting text to lowercase, removing urls,
# removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
# stemming, lemmatization, and sometimes removing emojis or special characters.
#
# good preprocessing can improve the quality of nlp models. however, preprocessing should be done carefully.
# for example, removing the word "not" from the sentence "i am not happy" can change the meaning completely.
# similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
# can contain useful information about topics, opinions, or trends.
#
# your task is to build a complete nlp preprocessing pipeline for this text.
# you should clean the text step by step and observe how the output changes after each step.

# %%
text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
text = re.sub(r'#\w+', '', text)

print(text)
# Out:
# natural language processing, also known as nlp, is one of the most important areas of artificial intelligence.
# today, companies use nlp in chatbots, search engines, recommendation systems, social media analytics,
# customer feedback analysis, automatic translation, and voice assistants.
#
# in 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
# online forms, tweets, product comments, and support tickets. however, this text data is often messy.
# for example, a customer may write: "i love this product!!! visit   ".
# another user may write: "the service was not good... i waited 45 minutes and no one replied."
#
# before applying machine learning or deep learning models, we need to clean and prepare the text.
# this step is called text preprocessing. it may include converting text to lowercase, removing urls,
# removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
# stemming, lemmatization, and sometimes removing emojis or special characters.
#
# good preprocessing can improve the quality of nlp models. however, preprocessing should be done carefully.
# for example, removing the word "not" from the sentence "i am not happy" can change the meaning completely.
# similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
# can contain useful information about topics, opinions, or trends.
#
# your task is to build a complete nlp preprocessing pipeline for this text.
# you should clean the text step by step and observe how the output changes after each step.

# %%
stop_words = set(stopwords.words("english"))
tokens = word_tokenize(text)

filtered_text = [
    text for text in tokens
    if text.lower() not in stop_words
]
print(filtered_text)
# Out:
# ['natural', 'language', 'processing', ',', 'also', 'known', 'nlp', ',', 'one', 'important', 'areas', 'artificial', 'intelligence', '.', 'today', ',', 'companies', 'use', 'nlp', 'chatbots', ',', 'search', 'engines', ',', 'recommendation', 'systems', ',', 'social', 'media', 'analytics', ',', 'customer', 'feedback', 'analysis', ',', 'automatic', 'translation', ',', 'voice', 'assistants', '.', '2026', ',', 'many', 'organizations', 'collecting', 'huge', 'amounts', 'text', 'data', 'websites', ',', 'emails', ',', 'reviews', ',', 'online', 'forms', ',', 'tweets', ',', 'product', 'comments', ',', 'support', 'tickets', '.', 'however', ',', 'text', 'data', 'often', 'messy', '.', 'example', ',', 'customer', 'may', 'write', ':', '``', 'love', 'product', '!', '!', '!', 'visit', '``', '.', 'another', 'user', 'may', 'write', ':', '``', 'service', 'good', '...', 'waited', '45', 'minutes', 'one', 'replied', '.', "''", 'applying', 'machine', 'learning', 'deep', 'learning', 'models', ',', 'need', 'clean', 'prepare', 'text', '.', 'step', 'called', 'text', 'preprocessing', '.', 'may', 'include', 'converting', 'text', 'lowercase', ',', 'removing', 'urls', ',', 'removing', 'punctuation', ',', 'removing', 'numbers', ',', 'tokenizing', 'sentences', 'words', ',', 'removing', 'stop', 'words', ',', 'stemming', ',', 'lemmatization', ',', 'sometimes', 'removing', 'emojis', 'special', 'characters', '.', 'good', 'preprocessing', 'improve', 'quality', 'nlp', 'models', '.', 'however', ',', 'preprocessing', 'done', 'carefully', '.', 'example', ',', 'removing', 'word', '``', "''", 'sentence', '``', 'happy', "''", 'change', 'meaning', 'completely', '.', 'similarly', ',', 'removing', 'hashtags', 'may', 'always', 'good', 'idea', 'social', 'media', 'analytics', 'hashtags', 'contain', 'useful', 'information', 'topics', ',', 'opinions', ',', 'trends', '.', 'task', 'build', 'complete', 'nlp', 'preprocessing', 'pipeline', 'text', '.', 'clean', 'text', 'step', 'step', 'observe', 'output', 'changes', 'step', '.']

# %%
porter = PorterStemmer()

print("tokens".ljust(15),
      "Stemmer".ljust(15))

print("-" * 40)

# stemmed_words = [porter.stem(word) for word in filtered_text]

for word in filtered_text:
    print(word.ljust(15),
          porter.stem(word).ljust(15))
# Out:
# tokens          Stemmer
# ----------------------------------------
# natural         natur
# language        languag
# processing      process
# ,               ,
# also            also
# known           known
# nlp             nlp
# ,               ,
# one             one
# important       import
# areas           area
# artificial      artifici
# intelligence    intellig
# .               .
# today           today
# ,               ,
# companies       compani
# use             use
# nlp             nlp
# chatbots        chatbot
# ,               ,
# search          search
# engines         engin
# ,               ,
# recommendation  recommend
# systems         system
# ,               ,
# social          social
# media           media
# analytics       analyt
# ,               ,
# customer        custom
# feedback        feedback
# analysis        analysi
# ,               ,
# automatic       automat
# translation     translat
# ,               ,
# voice           voic
# assistants      assist
# .               .
# 2026            2026
# ,               ,
# many            mani
# organizations   organ
# collecting      collect
# huge            huge
# amounts         amount
# text            text
# data            data
# websites        websit
# ,               ,
# emails          email
# ,               ,
# reviews         review
# ,               ,
# online          onlin
# forms           form
# ,               ,
# tweets          tweet
# ,               ,
# product         product
# comments        comment
# ,               ,
# support         support
# tickets         ticket
# .               .
# however         howev
# ,               ,
# text            text
# data            data
# often           often
# messy           messi
# .               .
# example         exampl
# ,               ,
# customer        custom
# may             may
# write           write
# :               :
# ``              ``
# love            love
# product         product
# !               !
# !               !
# !               !
# visit           visit
# ``              ``
# .               .
# another         anoth
# user            user
# may             may
# write           write
# :               :
# ``              ``
# service         servic
# good            good
# ...             ...
# waited          wait
# 45              45
# minutes         minut
# one             one
# replied         repli
# .               .
# ''              ''
# applying        appli
# machine         machin
# learning        learn
# deep            deep
# learning        learn
# models          model
# ,               ,
# need            need
# clean           clean
# prepare         prepar
# text            text
# .               .
# step            step
# called          call
# text            text
# preprocessing   preprocess
# .               .
# may             may
# include         includ
# converting      convert
# text            text
# lowercase       lowercas
# ,               ,
# removing        remov
# urls            url
# ,               ,
# removing        remov
# punctuation     punctuat
# ,               ,
# removing        remov
# numbers         number
# ,               ,
# tokenizing      token
# sentences       sentenc
# words           word
# ,               ,
# removing        remov
# stop            stop
# words           word
# ,               ,
# stemming        stem
# ,               ,
# lemmatization   lemmat
# ,               ,
# sometimes       sometim
# removing        remov
# emojis          emoji
# special         special
# characters      charact
# .               .
# good            good
# preprocessing   preprocess
# improve         improv
# quality         qualiti
# nlp             nlp
# models          model
# .               .
# however         howev
# ,               ,
# preprocessing   preprocess
# done            done
# carefully       care
# .               .
# example         exampl
# ,               ,
# removing        remov
# word            word
# ``              ``
# ''              ''
# sentence        sentenc
# ``              ``
# happy           happi
# ''              ''
# change          chang
# meaning         mean
# completely      complet
# .               .
# similarly       similarli
# ,               ,
# removing        remov
# hashtags        hashtag
# may             may
# always          alway
# good            good
# idea            idea
# social          social
# media           media
# analytics       analyt
# hashtags        hashtag
# contain         contain
# useful          use
# information     inform
# topics          topic
# ,               ,
# opinions        opinion
# ,               ,
# trends          trend
# .               .
# task            task
# build           build
# complete        complet
# nlp             nlp
# preprocessing   preprocess
# pipeline        pipelin
# text            text
# .               .
# clean           clean
# text            text
# step            step
# step            step
# observe         observ
# output          output
# changes         chang
# step            step
# .               .

# %%
nlp = spacy.load("en_core_web_sm")

# lemmas = []
doc = nlp(text)

print("toekns".ljust(15),
      "LEMMA".ljust(15),
      "POS TAG")
print("-" * 40)

for token in doc:
     print(token.text.ljust(15),
         token.lemma_.ljust(15),
           token.pos_)
# Out:
# toekns          LEMMA           POS TAG
# ----------------------------------------
#
#
#                SPACE
# natural         natural         ADJ
# language        language        NOUN
# processing      processing      NOUN
# ,               ,               PUNCT
# also            also            ADV
# known           know            VERB
# as              as              ADP
# nlp             nlp             NOUN
# ,               ,               PUNCT
# is              be              AUX
# one             one             NUM
# of              of              ADP
# the             the             DET
# most            most            ADV
# important       important       ADJ
# areas           area            NOUN
# of              of              ADP
# artificial      artificial      ADJ
# intelligence    intelligence    NOUN
# .               .               PUNCT
#
#
#                SPACE
# today           today           NOUN
# ,               ,               PUNCT
# companies       company         NOUN
# use             use             VERB
# nlp             nlp             NOUN
# in              in              ADP
# chatbots        chatbot         NOUN
# ,               ,               PUNCT
# search          search          NOUN
# engines         engine          NOUN
# ,               ,               PUNCT
# recommendation  recommendation  NOUN
# systems         system          NOUN
# ,               ,               PUNCT
# social          social          ADJ
# media           medium          NOUN
# analytics       analytic        NOUN
# ,               ,               PUNCT
#
#
#                SPACE
# customer        customer        NOUN
# feedback        feedback        NOUN
# analysis        analysis        NOUN
# ,               ,               PUNCT
# automatic       automatic       ADJ
# translation     translation     NOUN
# ,               ,               PUNCT
# and             and             CCONJ
# voice           voice           NOUN
# assistants      assistant       NOUN
# .               .               PUNCT
#
#
#
#
#               SPACE
# in              in              ADP
# 2026            2026            NUM
# ,               ,               PUNCT
# many            many            ADJ
# organizations   organization    NOUN
# are             be              AUX
# collecting      collect         VERB
# huge            huge            ADJ
# amounts         amount          NOUN
# of              of              ADP
# text            text            NOUN
# data            datum           NOUN
# from            from            ADP
# websites        website         NOUN
# ,               ,               PUNCT
# emails          email           NOUN
# ,               ,               PUNCT
# reviews         review          NOUN
# ,               ,               PUNCT
#
#
#                SPACE
# online          online          ADJ
# forms           form            NOUN
# ,               ,               PUNCT
# tweets          tweet           NOUN
# ,               ,               PUNCT
# product         product         NOUN
# comments        comment         NOUN
# ,               ,               PUNCT
# and             and             CCONJ
# support         support         NOUN
# tickets         ticket          NOUN
# .               .               PUNCT
# however         however         ADV
# ,               ,               PUNCT
# this            this            DET
# text            text            NOUN
# data            data            NOUN
# is              be              AUX
# often           often           ADV
# messy           messy           ADJ
# .               .               PUNCT
#
#
#                SPACE
# for             for             ADP
# example         example         NOUN
# ,               ,               PUNCT
# a               a               DET
# customer        customer        NOUN
# may             may             AUX
# write           write           VERB
# :               :               PUNCT
# "               "               PUNCT
# i               I               PRON
# love            love            VERB
# this            this            DET
# product         product         NOUN
# !               !               PUNCT
# !               !               PUNCT
# !               !               PUNCT
# visit           visit           VERB
#                                 SPACE
# "               "               PUNCT
# .               .               PUNCT
#
#
#                SPACE
# another         another         DET
# user            user            NOUN
# may             may             AUX
# write           write           VERB
# :               :               PUNCT
# "               "               PUNCT
# the             the             DET
# service         service         NOUN
# was             be              AUX
# not             not             PART
# good            good            ADJ
# ...             ...             PUNCT
# i               I               PRON
# waited          wait            VERB
# 45              45              NUM
# minutes         minute          NOUN
# and             and             CCONJ
# no              no              DET
# one             one             NOUN
# replied         reply           VERB
# .               .               PUNCT
# "               "               PUNCT
#
#
#
#
#               SPACE
# before          before          ADP
# applying        apply           VERB
# machine         machine         NOUN
# learning        learning        NOUN
# or              or              CCONJ
# deep            deep            ADJ
# learning        learning        NOUN
# models          model           NOUN
# ,               ,               PUNCT
# we              we              PRON
# need            need            VERB
# to              to              PART
# clean           clean           VERB
# and             and             CCONJ
# prepare         prepare         VERB
# the             the             DET
# text            text            NOUN
# .               .               PUNCT
#
#
#                SPACE
# this            this            DET
# step            step            NOUN
# is              be              AUX
# called          call            VERB
# text            text            NOUN
# preprocessing   preprocessing   NOUN
# .               .               PUNCT
# it              it              PRON
# may             may             AUX
# include         include         VERB
# converting      convert         VERB
# text            text            NOUN
# to              to              PART
# lowercase       lowercase       VERB
# ,               ,               PUNCT
# removing        remove          VERB
# urls            url             NOUN
# ,               ,               PUNCT
#
#
#                SPACE
# removing        remove          VERB
# punctuation     punctuation     NOUN
# ,               ,               PUNCT
# removing        remove          VERB
# numbers         number          NOUN
# ,               ,               PUNCT
# tokenizing      tokenize        VERB
# sentences       sentence        NOUN
# into            into            ADP
# words           word            NOUN
# ,               ,               PUNCT
# removing        remove          VERB
# stop            stop            NOUN
# words           word            NOUN
# ,               ,               PUNCT
#
#
#                SPACE
# stemming        stemming        NOUN
# ,               ,               PUNCT
# lemmatization   lemmatization   NOUN
# ,               ,               PUNCT
# and             and             CCONJ
# sometimes       sometimes       ADV
# removing        remove          VERB
# emojis          emoji           NOUN
# or              or              CCONJ
# special         special         ADJ
# characters      character       NOUN
# .               .               PUNCT
#
#
#
#
#               SPACE
# good            good            ADJ
# preprocessing   preprocessing   NOUN
# can             can             AUX
# improve         improve         VERB
# the             the             DET
# quality         quality         NOUN
# of              of              ADP
# nlp             nlp             NOUN
# models          model           NOUN
# .               .               PUNCT
# however         however         ADV
# ,               ,               PUNCT
# preprocessing   preprocessing   NOUN
# should          should          AUX
# be              be              AUX
# done            do              VERB
# carefully       carefully       ADV
# .               .               PUNCT
#
#
#                SPACE
# for             for             ADP
# example         example         NOUN
# ,               ,               PUNCT
# removing        remove          VERB
# the             the             DET
# word            word            NOUN
# "               "               PUNCT
# not             not             PART
# "               "               PUNCT
# from            from            ADP
# the             the             DET
# sentence        sentence        NOUN
# "               "               PUNCT
# i               I               PRON
# am              be              AUX
# not             not             PART
# happy           happy           ADJ
# "               "               PUNCT
# can             can             AUX
# change          change          VERB
# the             the             DET
# meaning         meaning         NOUN
# completely      completely      ADV
# .               .               PUNCT
#
#
#                SPACE
# similarly       similarly       ADV
# ,               ,               PUNCT
# removing        remove          VERB
# hashtags        hashtag         NOUN
# may             may             AUX
# not             not             PART
# always          always          ADV
# be              be              AUX
# a               a               DET
# good            good            ADJ
# idea            idea            NOUN
# in              in              ADP
# social          social          ADJ
# media           medium          NOUN
# analytics       analytic        NOUN
# because         because         SCONJ
# hashtags        hashtag         NOUN
#
#
#                SPACE
# can             can             AUX
# contain         contain         VERB
# useful          useful          ADJ
# information     information     NOUN
# about           about           ADP
# topics          topic           NOUN
# ,               ,               PUNCT
# opinions        opinion         NOUN
# ,               ,               PUNCT
# or              or              CCONJ
# trends          trend           NOUN
# .               .               PUNCT
#
#
#
#
#               SPACE
# your            your            PRON
# task            task            NOUN
# is              be              AUX
# to              to              PART
# build           build           VERB
# a               a               DET
# complete        complete        ADJ
# nlp             nlp             NOUN
# preprocessing   preprocessing   NOUN
# pipeline        pipeline        NOUN
# for             for             ADP
# this            this            DET
# text            text            NOUN
# .               .               PUNCT
#
#
#                SPACE
# you             you             PRON
# should          should          AUX
# clean           clean           VERB
# the             the             DET
# text            text            NOUN
# step            step            NOUN
# by              by              ADP
# step            step            NOUN
# and             and             CCONJ
# observe         observe         VERB
# how             how             SCONJ
# the             the             DET
# output          output          NOUN
# changes         change          VERB
# after           after           ADP
# each            each            DET
# step            step            NOUN
# .               .               PUNCT
#
#
#                SPACE

# %%
lemma = WordNetLemmatizer()

print("Word".ljust(15),
      "LEMMA".ljust(15),)

print("-" * 40)

for words in filtered_text:
    print(words.ljust(15),
          lemma.lemmatize(words).ljust(15))
# Out:
# Word            LEMMA
# ----------------------------------------
# natural         natural
# language        language
# processing      processing
# ,               ,
# also            also
# known           known
# nlp             nlp
# ,               ,
# one             one
# important       important
# areas           area
# artificial      artificial
# intelligence    intelligence
# .               .
# today           today
# ,               ,
# companies       company
# use             use
# nlp             nlp
# chatbots        chatbots
# ,               ,
# search          search
# engines         engine
# ,               ,
# recommendation  recommendation
# systems         system
# ,               ,
# social          social
# media           medium
# analytics       analytics
# ,               ,
# customer        customer
# feedback        feedback
# analysis        analysis
# ,               ,
# automatic       automatic
# translation     translation
# ,               ,
# voice           voice
# assistants      assistant
# .               .
# 2026            2026
# ,               ,
# many            many
# organizations   organization
# collecting      collecting
# huge            huge
# amounts         amount
# text            text
# data            data
# websites        website
# ,               ,
# emails          email
# ,               ,
# reviews         review
# ,               ,
# online          online
# forms           form
# ,               ,
# tweets          tweet
# ,               ,
# product         product
# comments        comment
# ,               ,
# support         support
# tickets         ticket
# .               .
# however         however
# ,               ,
# text            text
# data            data
# often           often
# messy           messy
# .               .
# example         example
# ,               ,
# customer        customer
# may             may
# write           write
# :               :
# ``              ``
# love            love
# product         product
# !               !
# !               !
# !               !
# visit           visit
# ``              ``
# .               .
# another         another
# user            user
# may             may
# write           write
# :               :
# ``              ``
# service         service
# good            good
# ...             ...
# waited          waited
# 45              45
# minutes         minute
# one             one
# replied         replied
# .               .
# ''              ''
# applying        applying
# machine         machine
# learning        learning
# deep            deep
# learning        learning
# models          model
# ,               ,
# need            need
# clean           clean
# prepare         prepare
# text            text
# .               .
# step            step
# called          called
# text            text
# preprocessing   preprocessing
# .               .
# may             may
# include         include
# converting      converting
# text            text
# lowercase       lowercase
# ,               ,
# removing        removing
# urls            url
# ,               ,
# removing        removing
# punctuation     punctuation
# ,               ,
# removing        removing
# numbers         number
# ,               ,
# tokenizing      tokenizing
# sentences       sentence
# words           word
# ,               ,
# removing        removing
# stop            stop
# words           word
# ,               ,
# stemming        stemming
# ,               ,
# lemmatization   lemmatization
# ,               ,
# sometimes       sometimes
# removing        removing
# emojis          emojis
# special         special
# characters      character
# .               .
# good            good
# preprocessing   preprocessing
# improve         improve
# quality         quality
# nlp             nlp
# models          model
# .               .
# however         however
# ,               ,
# preprocessing   preprocessing
# done            done
# carefully       carefully
# .               .
# example         example
# ,               ,
# removing        removing
# word            word
# ``              ``
# ''              ''
# sentence        sentence
# ``              ``
# happy           happy
# ''              ''
# change          change
# meaning         meaning
# completely      completely
# .               .
# similarly       similarly
# ,               ,
# removing        removing
# hashtags        hashtags
# may             may
# always          always
# good            good
# idea            idea
# social          social
# media           medium
# analytics       analytics
# hashtags        hashtags
# contain         contain
# useful          useful
# information     information
# topics          topic
# ,               ,
# opinions        opinion
# ,               ,
# trends          trend
# .               .
# task            task
# build           build
# complete        complete
# nlp             nlp
# preprocessing   preprocessing
# pipeline        pipeline
# text            text
# .               .
# clean           clean
# text            text
# step            step
# step            step
# observe         observe
# output          output
# changes         change
# step            step
# .               .
